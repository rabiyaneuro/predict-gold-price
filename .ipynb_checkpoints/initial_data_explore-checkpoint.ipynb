# %%
# SETUP


import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm

# %matplotlib inline

RND = 2020

# %%
# gold futures


gcf = yf.Ticker('GC=F').history(period="max")
gcf.head()
# Out:
#              Open   High    Low  Close  Volume  Dividends  Stock Splits
# Date
# 2000-02-28  292.3  292.5  292.3  292.5       4          0             0
# 2000-02-29  292.4  292.4  292.4  292.4       7          0             0
# 2000-03-01  291.5  291.5  291.5  291.5       0          0             0
# 2000-03-02  288.2  291.5  288.0  288.2     100          0             0
# 2000-03-03  288.8  288.8  288.8  288.8      10          0             0

# %%
gcf.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5110.000000  5110.000000  5110.000000  5110.000000  5.110000e+03
# mean    963.222270   968.117554   957.918689   963.129883  8.660913e+05
# std     473.321194   476.299069   469.895446   473.215310  9.664488e+06
# min     255.000000   256.100000   255.000000   255.100000  0.000000e+00
# 25%     430.325000   432.075000   430.250000   431.450000  1.500000e+01
# 50%    1118.400000  1124.400000  1110.150000  1117.750000  8.600000e+01
# 75%    1311.075000  1316.150000  1306.775000  1311.075000  3.620000e+02
# max    1909.000000  1911.600000  1864.000000  1888.700000  2.307245e+08
#
#        Dividends  Stock Splits
# count     5110.0        5110.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
gcf.tail()
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-07-15  1811.8  1819.5  1804.0  1815.0  96317140          0             0
# 2020-07-16  1812.5  1814.9  1794.1  1797.8  90726258          0             0
# 2020-07-17  1798.4  1813.9  1797.7  1812.1  85106830          0             0
# 2020-07-19  1812.3  1812.5  1809.8  1810.5    259521          0             0
# 2020-07-20  1808.9  1823.4  1807.4  1819.0  91580256          0             0

# %%
gcf.isna().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
gcf.loc['2020':].plot( alpha=0.5, figsize=(11, 15), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1197330d0>,
# ...
#       dtype=object)

# %%
gcf.loc['2020':].index.to_series().diff().max()
# Out:
# Timedelta('3 days 00:00:00')

# %%
"""
gold futures
SPDR GLD - gold investment fund
Barrick Gold Corporation (mining)

usd currency index
S&p500
dow jones
NASDAQ Composite
S&P/TSX Composite index

"""

tickers = ['GC=F',
           'GLD',
           'GOLD',
           'DX-Y.NYB?P=DX-Y.NYB',
           '^GSPC',
           '^DJI',
           '^IXIC',
           '^GSPTSE']

#gather 'close' values for each     
res = []     
for t in tickers:
    temp = yf.Ticker(t).history(period="max")['Close'].loc['2000':]
    temp.rename(t, inplace = True)
    res.append(temp)

all_close = pd.concat(res, axis = 1)

# %%
# subplots starting from certain year, looked at all then zoomed in
axes = all_close.loc['2000':].plot(marker='.', alpha=0.5, linestyle='None', 
                      figsize=(11, 15), subplots=True)

# %%
# subplots starting from certain year, looked at all then zoomed in
axes = all_close.loc['2020':].plot( alpha=0.5, 
                      figsize=(11, 15), subplots=True)

# %%
all_close.loc['2020-06':].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43 entries, 2020-06-01 to 2020-07-20
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GC=F                 42 non-null     float64
#  1   GLD                  35 non-null     float64
#  2   GOLD                 35 non-null     float64
#  3   DX-Y.NYB?P=DX-Y.NYB  35 non-null     float64
#  4   ^GSPC                35 non-null     float64
#  5   ^DJI                 35 non-null     float64
#  6   ^IXIC                35 non-null     float64
#  7   ^GSPTSE              35 non-null     float64
# dtypes: float64(8)
# memory usage: 3.0 KB

# %%
# more viz of gold futures
end_dt = '2020-07-17'
data = gcf.loc[:end_dt]['Close']
data.tail()
# Out:
# Date
# 2020-07-13    1801.9
# 2020-07-14    1812.9
# 2020-07-15    1815.0
# 2020-07-16    1797.8
# 2020-07-17    1812.1
# Name: Close, dtype: float64

# %%
data.plot(x='Date',y='Close Price',figsize=(15,6),linestyle='--', markerfacecolor='r',color='y',markersize=.0005)

plt.xlabel('Date')
plt.ylabel('Close Price')
# Out:
# Text(0, 0.5, 'Close Price')

# %%
pd.plotting.lag_plot(data)

# %%
from mpl_toolkits import mplot3d
data = gcf.loc['2013':end_dt]['Close']


ax = plt.axes(projection='3d')
df = data.reset_index()
df['Month_name']=df['Date'].dt.month
df['Year']=df['Date'].dt.year
# Data for three-dimensional scattered points
ydata = df['Year']
xdata = df['Month_name']
zdata = df['Close']
ax.scatter3D(xdata, ydata, zdata, c=zdata)

# %%
decomposition = sm.tsa.seasonal_decompose(data.asfreq('d').interpolate(method='time'), model='additive')
fig = decomposition.plot()
plt.show()

#https://medium.com/@drnesr/filling-gaps-of-a-time-series-using-python-d4bfddd8c460

# %%
temp = data.asfreq('d')

temp.interpolate(method='time')
# Out:
# Date
# 2013-01-02    1687.900000
# 2013-01-03    1673.700000
# 2013-01-04    1648.100000
# 2013-01-05    1647.233333
# 2013-01-06    1646.366667
#                  ...
# 2020-07-13    1801.900000
# 2020-07-14    1812.900000
# 2020-07-15    1815.000000
# 2020-07-16    1797.800000
# 2020-07-17    1812.100000
# Freq: D, Name: Close, Length: 2754, dtype: float64

# %%
data.asfreq('d')
# Out:
# Date
# 2013-01-02    1687.9
# 2013-01-03    1673.7
# 2013-01-04    1648.1
# 2013-01-05       NaN
# 2013-01-06       NaN
#                ...
# 2020-07-13    1801.9
# 2020-07-14    1812.9
# 2020-07-15    1815.0
# 2020-07-16    1797.8
# 2020-07-17    1812.1
# Freq: D, Name: Close, Length: 2754, dtype: float64

# %%
gcf = yf.Ticker('GC=F').history(period="max")

gcf.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
gcf.asfreq('d')
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 2000-02-28   292.3   292.5   292.3   292.5         4.0        0.0
# 2000-02-29   292.4   292.4   292.4   292.4         7.0        0.0
# 2000-03-01   291.5   291.5   291.5   291.5         0.0        0.0
# 2000-03-02   288.2   291.5   288.0   288.2       100.0        0.0
# 2000-03-03   288.8   288.8   288.8   288.8        10.0        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2020-07-17  1798.4  1813.9  1797.7  1812.1  85106830.0        0.0
# 2020-07-18     NaN     NaN     NaN     NaN         NaN        NaN
# 2020-07-19  1812.3  1812.5  1809.8  1810.5    259521.0        0.0
# 2020-07-20  1808.9  1823.4  1807.4  1819.6  91680403.0        0.0
# 2020-07-21  1822.2  1822.9  1818.8  1819.2   3111942.0        0.0
#
#             Stock Splits
# Date
# 2000-02-28           0.0
# 2000-02-29           0.0
# 2000-03-01           0.0
# 2000-03-02           0.0
# 2000-03-03           0.0
# ...
